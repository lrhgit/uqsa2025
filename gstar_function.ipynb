# %% [markdown]
# # Sensitivity indices for Sobol's $G^{*}$ function
#
# **Leif Rune Hellevik**

# %% [markdown]
# ## Setup

# %%
# --- cell: install_chaospy ---
# @title Install chaospy (Colab-friendly)

try:
    import chaospy as cp
    import numpoly
    import numpy as np
    print("chaospy er allerede installert.")
except ImportError:
    # Installer chaospy fra PyPI. Dette drar inn numpoly automatisk.
    # %pip install chaospy==4.3.21 --no-cache-dir
    import chaospy as cp
    import numpoly
    import numpy as np

print("numpy  :", np.__version__)
print("numpoly:", numpoly.__version__)
print("chaospy:", cp.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.5/254.5 kB 326.1 MB/s eta 0:00:00
# ...
#   Created wheel for numpoly: filename=numpoly-1.3.9-cp312-cp312-linux_x86_64.whl size=1109774 sha256=d0d6cf35b77b4795c73172618a1d1318cb5ecd84823f9cb037aeb4ffdebc9627
#   Stored in directory: /tmp/pip-ephem-wheel-cache-odn7pgzq/wheels/3b/b9/a0/aaf362cdd052e668c38a5b2270f4fc8f613c254dce679a00ed
# Successfully built numpoly
# ...
# numpy  : 2.0.2
# numpoly: 1.3.9
# chaospy: 4.3.21

# %%
# --- cell: repo_setup ---
# @title Repo sync and environment setup

import os
import sys
import subprocess
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
REMOTE = "https://github.com/lrhgit/uqsa2025.git"
REPO_PATH_COLAB = Path("/content/uqsa2025")

if IN_COLAB:
    if not REPO_PATH_COLAB.exists():
        print("Cloning repository...")
        subprocess.run(
            ["git", "clone", REMOTE, str(REPO_PATH_COLAB)],
            check=True
        )
    else:
        print("Updating existing repository...")
        subprocess.run(
            ["git", "-C", str(REPO_PATH_COLAB), "pull"],
            check=True
        )
    os.chdir(REPO_PATH_COLAB)

# --- Find repo root (works locally + in Colab) ---
cwd = Path.cwd().resolve()
repo_root = next(
    (p for p in [cwd] + list(cwd.parents) if (p / ".git").exists()),
    cwd
)

PY_SRC = repo_root / "python_source"
if PY_SRC.exists() and str(PY_SRC) not in sys.path:
    sys.path.insert(0, str(PY_SRC))

print("CWD:", Path.cwd())
print("repo_root:", repo_root)
print("python_source exists:", PY_SRC.exists())
print("python_source in sys.path:", str(PY_SRC) in sys.path)
# Out:
# Cloning repository...
# CWD: /content/uqsa2025
# repo_root: /content/uqsa2025
# python_source exists: True
# python_source in sys.path: True

# %%
# --- cell: layout_and_numpy_patch ---
# @title Layout fix, imports, and NumPy compatibility patch

import warnings
warnings.filterwarnings("ignore")

from IPython.display import HTML

HTML("""
<style>
div.cell.code_cell, div.output {
    max-width: 100% !important;
}
</style>
""")

import numpy as np
import matplotlib.pyplot as plt
import chaospy as cp
import numpoly
import pandas as pd

import ipywidgets as widgets
from IPython.display import display, clear_output
from plot_sobol import plot_sobol_bars


# Pretty-print helpers (used across notebooks)
from pretty_printing import section_title, pretty_table, pretty_print_sobol_mc


# --- NumPy reshape compatibility patch for numpoly ---
_old_reshape = np.reshape

def _reshape_compat(a, *args, **kwargs):
    newshape = None
    if "newshape" in kwargs:
        newshape = kwargs.pop("newshape")
    if "shape" in kwargs and newshape is None:
        newshape = kwargs.pop("shape")
    if newshape is not None:
        return _old_reshape(a, newshape, *args, **kwargs)
    return _old_reshape(a, *args, **kwargs)

np.reshape = _reshape_compat
print("✓ numpy.reshape patched for numpoly compatibility")
# Out:
# ✓ numpy.reshape patched for numpoly compatibility

# %% [markdown]
# ## Why Sobol's $G^{*}$?
#
# The Sobol' $G^{*}$ function is a standard benchmark in global sensitivity analysis.
#
# Its main advantage is that analytical Sobol indices are available, allowing exact results to be compared with numerical approximations.
#
# The function naturally exhibits both varying factor importance and interaction effects, making it useful for illustrating first-order and total-effect sensitivity indices.

# %% [markdown]
# ## The $G^{*}$ benchmark function
#
# The Sobol’ $G^{*}$ function extends the original Sobol $G$-function by introducing **shape** ($\alpha_i$) and **shift** ($\delta_i$) parameters. This makes it possible to explore nonlinearity and interaction effects in a controlled setting while retaining analytical sensitivity indices.
#
# The mathematical form is
#
# $$
# Y = G(X)
# = \prod_{i=1}^{k} g_i
# $$
#
# with
#
# $$
# g_i =
# \frac{
# (1+\alpha_i)
# \left|
# 2\left(X_i+\delta_i-\lfloor X_i+\delta_i \rfloor\right)-1
# \right|^{\alpha_i}
# +a_i
# }{
# 1+a_i
# }.
# $$
#
# **The multiplicative structure naturally introduces interaction effects.**
#
# The input factors $X_i$ are assumed uniformly distributed on $[0,1]$, with
#
# - $a_i \ge 0$ controlling factor importance
# - $\alpha_i > 0$ controlling nonlinearity / shape
# - $\delta_i \in [0,1]$ introducing a shift
#
# For $\alpha_i = 1$ and $\delta_i = 0$, the model reduces to the original Sobol $G$-function.
#
# A useful practical observation is that small values of $a_i$ lead to larger sensitivity indices, meaning that the corresponding input has greater influence on the output variance.

# %%
def G(X, a, alpha, delta):
    z = X + delta
    frac = z - np.floor(z)
    g_terms = ((1 + alpha) * np.abs(2 * frac - 1)**alpha + a) / (1 + a)
    return np.prod(g_terms, axis=1)

# %% [markdown]
# ## Analytical reference indices
#
# For the Sobol $G^{*}$ function, analytical expressions are available for both first-order and total-effect Sobol indices.
#
# These provide exact reference values that we can compare with numerical estimates obtained later using Monte Carlo sampling and polynomial chaos expansions.

# %%
# Analytical Sobol indices for the G* function

def V_i(a_i, alpha_i):
    """Partial variance contribution for factor i."""
    return alpha_i**2 / ((1 + 2 * alpha_i) * (1 + a_i)**2)


def V_total(a, alpha):
    """Total variance."""
    D = 1.0
    for a_i, alpha_i in zip(a, alpha):
        D *= (1.0 + V_i(a_i, alpha_i))
    return D - 1.0


def S_first(a, alpha):
    """First-order Sobol indices."""
    Vtot = V_total(a, alpha)
    return np.array([V_i(a_i, alpha_i) / Vtot
                     for a_i, alpha_i in zip(a, alpha)])


def S_total(a, alpha):
    """Total-effect Sobol indices."""
    Vtot = V_total(a, alpha)
    return np.array([
        ((Vtot + 1.0) / (V_i(a_i, alpha_i) + 1.0)) * V_i(a_i, alpha_i) / Vtot
        for a_i, alpha_i in zip(a, alpha)
    ])

# %%
# @title
# Interactive exploration of analytical Sobol indices

from slider_helpers import build_slider_interface, make_slider_dict

default_values = {
    "a1": 0.75, "a2": 0.80, "a3": 0.20, "a4": 0.20,
    "alpha1": 0.75, "alpha2": 0.20, "alpha3": 0.20, "alpha4": 0.20,
}

sliders = make_slider_dict(
    prefixes=["a", "alpha"],
    count=4,
    default_values=default_values,
    slider_ranges={
        "a": (0.0, 2.0, 0.05),
        "alpha": (0.0, 1.0, 0.05),
    },
)

def plot_sensitivities(**kwargs):
    a = np.array([kwargs[f"a{i}"] for i in range(1, 5)], dtype=float)
    alpha = np.array([kwargs[f"alpha{i}"] for i in range(1, 5)], dtype=float)

    Si = S_first(a, alpha)
    ST = S_total(a, alpha)

    fig, ax = plt.subplots(constrained_layout=True)
    #plot_sobol_bars(ax, Si, ST, title="Sobol G* sensitivities")
    plot_sobol_bars(ax, Si, ST, title="")
    fig.suptitle(
    r"$g_i=\frac{(1+\alpha_i)"
    r"\left|2(X_i+\delta_i-\lfloor X_i+\delta_i\rfloor)-1\right|^{\alpha_i}+a_i}"
    r"{1+a_i}$",
    fontsize=13,
    )
    plt.show()
    plt.close(fig)


build_slider_interface(sliders, plot_sensitivities, sliders_per_row=4)
# Out:
# ...
# Output()

# %% [markdown]
# ###Reflection
# Use the sliders to explore how the Sobol indices change.
#  * Which parameters dominate the output uncertainty?
#
#  * When do first-order and total indices differ?
#
#  * What does this indicate about interactions?

# %% [markdown]
# **Note on the parameter $\delta$**
#
# Analytically, the Sobol indices of the $G^*$ function depend only on $(a_i, \alpha_i)$, not on $\delta_i$.
#
# In the numerical Monte Carlo and PCE approximations below, however, changing $\delta_i$ can still affect the finite-sample or finite-order estimates. This is useful to keep in mind: numerical approximations may show method-dependent variation even when the analytical sensitivity indices are invariant.

# %% [markdown]
# ## Comparison of analytical, MC and PCE Sobol indices
#
# We now compare analytical Sobol indices with estimates obtained from Monte Carlo sampling and polynomial chaos expansions.

# %%
from monte_carlo import generate_sample_matrices_mc, calculate_sensitivity_indices_mc
from slider_helpers import build_slider_interface, make_slider_dict, make_int_slider
from pretty_printing import (
    section_title,
    relative_error,
    sobol_table,
    display_side_by_side_tables,
    parameter_array,
)

default_values = {
    "a1": 0.75, "a2": 0.80, "a3": 0.20, "a4": 0.20,
    "alpha1": 0.75, "alpha2": 0.20, "alpha3": 0.20, "alpha4": 0.20,
    "delta1": 0.60, "delta2": 0.50, "delta3": 0.20, "delta4": 0.20,
}

controls = make_slider_dict(
    prefixes=["a", "alpha", "delta"],
    count=4,
    default_values=default_values,
    slider_ranges={
        "a": (0.0, 2.0, 0.05),
        "alpha": (0.0, 1.0, 0.05),
        "delta": (0.0, 1.0, 0.05),
    },
)

controls.update({
    "NsMC": make_int_slider("NsMC", 10000, 2000, 120000, 2000),
    "NsPC": make_int_slider("NsPC", 1000, 200, 10000, 400),
    "p": make_int_slider("p", 2, 1, 6, 1),
})


def compute_mc_indices(a, alpha, delta, Ns):
    k = len(a)
    jpdf = cp.Iid(cp.Uniform(0, 1), k)
    A, B, C = generate_sample_matrices_mc(Ns, k, jpdf, sample_method="R")

    f_A = G(A, a, alpha, delta)
    f_B = G(B, a, alpha, delta)
    f_C = np.array([G(C[i], a, alpha, delta) for i in range(k)])

    return calculate_sensitivity_indices_mc(f_A, f_B, f_C)


def compute_pce_indices(a, alpha, delta, Ns, p):
    k = len(a)
    jpdf = cp.Iid(cp.Uniform(0, 1), k)

    X = jpdf.sample(Ns, rule="random", seed=12345)
    y = G(np.ascontiguousarray(X.T), a, alpha, delta)

    poly = cp.expansion.stieltjes(p, jpdf)
    approx = cp.fit_regression(poly, X, y)

    return (
        np.asarray(cp.Sens_m(approx, jpdf), dtype=float).ravel(),
        np.asarray(cp.Sens_t(approx, jpdf), dtype=float).ravel(),
    )


def compare_methods(**kwargs):
    a = parameter_array(kwargs, "a")
    alpha = parameter_array(kwargs, "alpha")
    delta = parameter_array(kwargs, "delta")

    NsMC = int(kwargs["NsMC"])
    NsPC = int(kwargs["NsPC"])
    p = int(kwargs["p"])

    Si_ref = S_first(a, alpha)
    ST_ref = S_total(a, alpha)

    Si_mc, ST_mc = compute_mc_indices(a, alpha, delta, NsMC)
    Si_pce, ST_pce = compute_pce_indices(a, alpha, delta, NsPC, p)

    labels = [f"X{i}" for i in range(1, len(a) + 1)]

    display(section_title(
        f"Sobol indices: analytical vs MC vs PCE "
        f"(NsMC={NsMC}, NsPC={NsPC}, p={p})"
    ))

    display_side_by_side_tables([
        ("First-order indices", sobol_table(Si_ref, Si_mc, Si_pce, labels)),
        ("Total-effect indices", sobol_table(ST_ref, ST_mc, ST_pce, labels)),
    ])


build_slider_interface(controls, compare_methods, sliders_per_row=4)
# Out:
# ...
# Output()

# %% [markdown]
# ###Reflections
#
# Compare the analytical, Monte Carlo, and PCE estimates.
#
# Consider:
#
# * Are the rankings of parameters consistent across methods?
#
# * When do first-order and total-effect indices differ?
#
# * What happens when you change $\delta$?
#
# * Why do the analytical indices stay unchanged, while the MC and PCE estimates may change?
#
# * Which differences matter for interpretation — and which are numerical artefacts?

# %% [markdown]
# ## References
#
# 1. <span id="Azzini_func_2022"></span> **I. Azzini and R. Rosati**.  A Function Dataset for Benchmarking in Sensitivity Analysis, *Data in Brief*, 42, pp. 108071, [doi: https://doi.org/10.1016/j.dib.2022.108071](https://dx.doi.org/https://doi.org/10.1016/j.dib.2022.108071), 2022, <https://www.sciencedirect.com/science/article/pii/S2352340922002827>.
