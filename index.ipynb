# %% [markdown]
# <!-- File automatically generated using DocOnce (https://github.com/doconce/doconce/):
# doconce format ipynb index.do.txt --encoding=utf-8 --ipynb_admon=hrule --ipynb_disable_mpl_inline --ipynb_cite=latex-plain -->
#
# # Uncertainty Quantification and Sensitivity Analysis: Methods and Applications
#
# **Leif Rune Hellevik**, NTNU
#
# Date: **January 2026**
#
# A set of notebooks has been developed and collected in this repository
# to introduce methods and applications in uncertainty quantification
# and sensitivity analysis (UQSA).
#
# Below you find a hyperlinked overview of the seminar material. Each notebook can be run locally or opened directly in Google Colab.
#
# * **Preliminaries** Local: [preliminaries.ipynb](/lab/tree/preliminaries.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/preliminaries.ipynb) Presents the statistical relations and laws needed to derive the Sobol indices.
#
# * **Introduction to sensitivity analysis** Local: [sensitivity_introduction.ipynb](/lab/tree/sensitivity_introduction.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/sensitivity_introduction.ipynb)
#
# * **Monte Carlo methods for UQSA** Local: [monte_carlo.ipynb](/lab/tree/monte_carlo.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/monte_carlo.ipynb)
#
# * **Polynomial chaos expansion methods for UQSA** Local: [introduction_gpc.ipynb](/lab/tree/introduction_gpc.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/introduction_gpc.ipynb)
#
# * **Exercises** Local: [exercises.ipynb](/lab/tree/exercises.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/exercises.ipynb)
#
# * **UQSA of arterial wall models** Local: [wall_models.ipynb](/lab/tree/wall_models.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/wall_models.ipynb)
#
# * **UQSA of the Ishigami function** Local: [ishigami_example.ipynb](/lab/tree/ishigami_example.ipynb) Colab: [colab link](https://colab.research.google.com/github/lrhgit/uqsa2025/blob/main/ishigami_example.ipynb)

# %% [markdown]
# # Acknowledgement
# The present notebooks build on earlier work developed with contributions
# from my former PhD-students Jacob Sturdy and Vinzenz Eck.
